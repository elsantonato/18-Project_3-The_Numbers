# %%
import pandas as pd
import csv

# %%
# Make a reference to the election_data.csv file path
csv_path = "data_materials/Invoices-2018/328-MEIC-Table-1.csv"

# Set the name and path for file to output
#file_to_output = "328-MEIC-Table.txt"

# %%
df = pd.read_csv(csv_path, index_col=False, header=0);
serie = df.transpose() # here we convert the DataFrame into a Serie
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-3e932b0c6060> in <module>()
# ----> 1 df = pd.read_csv(csv_path, index_col=False, header=0);
#       2 serie = df.transpose() # here we convert the DataFrame into a Serie
#
# ...

# %%
# Import the election_data.csv file as a DataFrame
#invoices_df = pd.read_csv(csv_path, encoding="utf-8")
#invoices_df
# Out:
#                                                                                                             Table 1
# NaN NaN                                                NaN NaN       INVOICE                                    NaN
#                                                                      NaN                                        NaN
#     FTP MEDIA                                          NaN NaN       NaN                                        NaN
#     23 Florida Crescent                                NaN NaN       NaN                                        NaN
#     Toronto, ON M9M 1P4                                NaN NaN       NaN                                        NaN
#     Mobile: 416-702-4387                               NaN CLIENT:   MEIC                                       NaN
#     www.ftpmedia.com                                   NaN CONTACT:  Kathleen Webb                              NaN
# ...

# %%
# drop null rows
no_null_df = invoices_df.dropna(how='any')
no_null_df
# Out:
#                                                                                  Table 1
# NaN ELEMENT                 NaN  QUANTITY RATE                                      COST
#     Producer-Mentor         NaN 1         (flat)                             $\t2,500.00
#     NaN                     NaN NaN       FIRST INSTALLMENT (1/3 of total):      $750.00
#                                           HST:                                    $97.50
#     HST#: 88318 6702 RT0001 NaN NaN       TOTAL:                                 $847.50
